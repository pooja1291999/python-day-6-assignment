# %%
a=[]
b=[]
n=int(input("enter the value"))
for i in range(0,n):
    x=int(input())
    a.append(x)
n=int(input("enter the value"))
for i in range(0,n):
    y=int(input())
    b.append(y)
a=a+b
l=len(a)
r=[]
for i in range(l):
    r.append(min(a))
    a.remove(min(a))
print("the list is"+str(r))
# Out:
# enter the value 6
#  10
#  20
#  40
#  60
#  70
#  80
# enter the value 6
#  5
#  15
#  25
#  35
#  45
#  60
# the list is[5, 10, 15, 20, 25, 35, 40, 45, 60, 60, 70, 80]
